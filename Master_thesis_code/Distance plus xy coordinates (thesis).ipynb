# %%
# import the necessary packages
from imutils import paths
import numpy as np
import imutils
import os
import cv2
def find_marker(image):
    # convert the image to grayscale, blur it, and detect edges
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)
    edged = cv2.Canny(gray, 35, 125)
    # find the contours in the edged image and keep the largest one;
    # we'll assume that this is our piece of paper in the image
    #cnts,hierarchy = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    #cnts,hierarchy = cv2.findContours(closed.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    items = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(items)
    for c in cnts:
        if cv2.contourArea(c) <= 50 :
            continue    
        x,y,w,h = cv2.boundingRect(c)
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255,0), 2)
        center = (x,y)
        print (center)
        
    #cnts = imutils.grab_contours(cnts)
    c = max(cnts, key = cv2.contourArea)
    # compute the bounding box of the of the paper region and return it
    return cv2.minAreaRect(c)

def distance_to_camera(knownWidth, focalLength, perWidth):
	# compute and return the distance from the maker to the camera
	return (knownWidth * focalLength) / perWidth

# initialize the known distance from the camera to the object, which
# in this case is 24 inches
KNOWN_DISTANCE = 24.0
# initialize the known object width, which in this case, the piece of
# paper is 12 inches wide
KNOWN_WIDTH = 11.0
# load the furst image that contains an object that is KNOWN TO BE 2 feet
# from our camera, then find the paper marker in the image, and initialize
# the focal length
image = cv2.imread("C:/Users/MANDEEP SINGH SHERRY/Desktop/practise/chair4444.jpg")
marker = find_marker(image)
focalLength = (marker[1][0] * KNOWN_DISTANCE) / KNOWN_WIDTH


def clear():
    os.system( 'cls' )
    
# loop over the images
for imagePath in sorted(paths.list_images("C:/Users/MANDEEP SINGH SHERRY/Desktop/practise")):
 # load the image, find the marker in the image, then compute the
 # distance to the marker from the camera
 clear()
 print(imagePath)
 image = cv2.imread(imagePath)
 marker = find_marker(image)
 inches = distance_to_camera(KNOWN_WIDTH, focalLength, marker[1][0])
 # draw a bounding box around the image and display it
 box = cv2.cv.BoxPoints(marker) if imutils.is_cv2() else cv2.boxPoints(marker)
 box = np.int0(box)
 cv2.drawContours(image, [box], -1, (0, 255, 0), 2)
 cv2.putText(image, "%.2fft" % (inches / 12),
 (image.shape[1] - 200, image.shape[0] - 20), cv2.FONT_HERSHEY_SIMPLEX,
  2.0, (0, 255, 0), 3)
 cv2.imshow("image", image)
 cv2.waitKey(0)
# Out:
# (27, 105)
# (66, 0)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\ChairAndSpecs.jpg
# (113, 142)
# (350, 108)
# (27, 104)
# (155, 102)
# (391, 68)
# (324, 28)
# (186, 23)
# (66, 0)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\b4.jpg
# (3, 62)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\camera_bed275.jpg
# (20, 96)
# (123, 94)
# (118, 91)
# (138, 70)
# (45, 63)
# (145, 53)
# (23, 47)
# (0, 0)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\camera_bottle236.jpg
# (113, 118)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\camera_table249.jpg
# (64, 126)
# (56, 105)
# (65, 102)
# (81, 100)
# (94, 91)
# (145, 85)
# (168, 84)
# (59, 81)
# (10, 72)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\chair4444.jpg
# (27, 105)
# (66, 0)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\chair4444_win.png
# (28, 118)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\chair_4444_max.png
# (25, 139)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\chair_4444_min.png
# (28, 148)
# (26, 137)
# (15, 14)
# (61, 0)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\chair_bottle14.jpg
# (95, 82)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\chair_bottle_WGH3.jpg
# (25, 150)
# (29, 127)
# (148, 101)
# (52, 21)
# (75, 17)
# (36, 17)
# (27, 12)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\chair_sp1.png
# (181, 109)
# (45, 98)
# (51, 23)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\chair_specs.png
# (27, 138)
# (165, 67)
# (16, 23)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\dst.jpg
# (17, 23)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\f1.jpg
# (102, 22)
# C:/Users/MANDEEP SINGH SHERRY/Desktop/practise\f2.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-fdc51af7aa7c> in <module>
#      57  print(imagePath)
#      58  image = cv2.imread(imagePath)
# ---> 59  marker = find_marker(image)
#      60  inches = distance_to_camera(KNOWN_WIDTH, focalLength, marker[1][0])
#      61  # draw a bounding box around the image and display it
#
# <ipython-input-1-fdc51af7aa7c> in find_marker(image)
#      25
#      26     #cnts = imutils.grab_contours(cnts)
# ---> 27     c = max(cnts, key = cv2.contourArea)
#      28     # compute the bounding box of the of the paper region and return it
#      29     return cv2.minAreaRect(c)
#
# ValueError: max() arg is an empty sequence
