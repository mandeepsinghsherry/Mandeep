# %%
import pywt
import cv2
import numpy as np
import pandas as pd
import glob
from PIL import Image
import tensorflow as tf

# %%
# This function does the coefficient fusing according to the fusion method
def fuseCoeff(cooef1, cooef2, method):

    if (method == 'mean'):
        cooef = (cooef1 + cooef2) / 2
    elif (method == 'min'):
        cooef = np.minimum(cooef1,cooef2)
    elif (method == 'max'):
        cooef = np.maximum(cooef1,cooef2)
    else:
        cooef = []

    return cooef


# Params
FUSION_METHOD = 'mean' # Can be 'min' || 'max || anything you choose according theory

# Read the two image
I1 = cv2.imread('C:/Users/MANDEEP SINGH SHERRY/Desktop/practise/sp1.jpg',0)
I2 = cv2.imread('C:/Users/MANDEEP SINGH SHERRY/Desktop/practise/specs2.jpg',0)

# We need to have both images the same size
I2 = cv2.resize(I2,I1.shape) # I do this just because i used two random images

## Fusion algo

# First: Do wavelet transform on each image
wavelet = 'db1'
cooef1 = pywt.wavedec2(I1[:,:], wavelet)
cooef2 = pywt.wavedec2(I2[:,:], wavelet)
print(cooef1)

# Second: for each level in both image do the fusion according to the desire option
fusedCooef = []
for i in range(len(cooef1)-1):

    # The first values in each decomposition is the apprximation values of the top level
    if(i == 0):

        fusedCooef.append(fuseCoeff(cooef1[0],cooef2[0],FUSION_METHOD))

    else:

        # For the rest of the levels we have tupels with 3 coeeficents
        c1 = fuseCoeff(cooef1[i][0],cooef2[i][0],FUSION_METHOD)
        c2 = fuseCoeff(cooef1[i][1], cooef2[i][1], FUSION_METHOD)
        c3 = fuseCoeff(cooef1[i][2], cooef2[i][2], FUSION_METHOD)

        fusedCooef.append((c1,c2,c3))

# Third: After we fused the cooefficent we nned to transfor back to get the image
fusedImage = pywt.waverec2(fusedCooef, wavelet)

# Forth: normmalize values to be in uint8
fusedImage = np.multiply(np.divide(fusedImage - np.min(fusedImage),(np.max(fusedImage) - np.min(fusedImage))),255)
fusedImage = fusedImage.astype(np.uint8)

# Fith: Show image
cv2.imwrite("C:/Users/MANDEEP SINGH SHERRY/Desktop/practise/specs2_sp1.jpg",fusedImage)
# Out:
# [array([[18134.2734375, 15666.3046875],
#        [13001.671875 , 11628.875    ]]), (array([[5264.7578125, 1657.8203125],
#        [1423.453125 , 1250.859375 ]]), array([[3526.0078125, 1814.8046875],
#        [-218.59375  ,  350.1875   ]]), array([[2139.4296875, 1268.9140625],
#        [-314.15625  ,  520.296875 ]])), (array([[ 1208.453125, -1880.421875, -1246.171875, -2157.578125],
#        [ 1900.078125,  3158.96875 ,  3542.65625 ,   760.515625],
#        [ -488.09375 , -2475.28125 , -2857.953125,  -266.125   ],
#        [ -325.109375,  -382.671875,  -246.046875,  -437.9375  ]]), array([[  602.046875,  -134.390625,  -613.859375,  1801.203125],
#        [  184.234375,  -416.625   ,  -497.      ,  1977.296875],
#        [-1469.8125  ,  -910.1875  ,  -489.546875,  1965.625   ],
#        [ -168.828125,   168.828125,   109.078125,   -53.9375  ]]), array([[ -35.671875,   29.390625, -136.140625,  -96.578125],
#        [-516.171875,  332.9375  , -174.96875 ,  714.515625],
# ...

# %%
# import pywt
# import cv2
# import numpy as np

# # This function does the coefficient fusing according to the fusion method
# def fuseCoeff(cooef1, cooef2, method):

#     if (method == 'mean'):
#         cooef = (cooef1 + cooef2) / 2
#     elif (method == 'min'):
#         cooef = np.minimum(cooef1,cooef2)
#     elif (method == 'max'):
#         cooef = np.maximum(cooef1,cooef2)
#     else:
#         cooef = []

#     return cooef


# # Params
# FUSION_METHOD = 'mean' # Can be 'min' || 'max || anything you choose according theory

# # Read the two image
# I1 = cv2.imread('C:/Users/MANDEEP SINGH SHERRY/Desktop/practise/nowchair.jpg',0)
# I2 = cv2.imread('C:/Users/MANDEEP SINGH SHERRY/Desktop/practise/chair4444.jpg',0)
# print(I1)
# Out:
# False
